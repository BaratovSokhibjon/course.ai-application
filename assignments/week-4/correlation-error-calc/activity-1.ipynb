# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
actual = np.array([200, 220, 250])
predicted = np.array([210, 215, 240])

# %%
correlation = np.corrcoef(actual, predicted)[0, 1]

mae = mean_absolute_error(actual, predicted)
rmse = np.sqrt(mean_squared_error(actual, predicted))

mean_actual = np.mean(actual)
rae = np.sum(np.abs(actual - predicted)) / np.sum(np.abs(actual - mean_actual))

rrse = np.sqrt(np.sum((actual - predicted) ** 2) / np.sum((actual - mean_actual) ** 2))

print(f"Correlation coefficient (r): {correlation:.3f}")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
print(f"Relative Absolute Error (RAE): {rae:.3f}")
print(f"Root Relative Squared Error (RRSE): {rrse:.3f}")
# Out:
# Correlation coefficient (r): 0.968
# Mean Absolute Error (MAE): 8.333
# Root Mean Squared Error (RMSE): 8.660
# Relative Absolute Error (RAE): 0.469
# Root Relative Squared Error (RRSE): 0.421

# %%
# Study Hours and Exam Scores
import numpy as np
import matplotlib.pyplot as plt

study_hours = np.array([2, 4, 6, 8, 10])
exam_scores = np.array([50, 55, 65, 70, 85])

# Scatter plot
plt.scatter(study_hours, exam_scores, color='blue')
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.title('Study Hours vs Exam Scores')
plt.grid(True)
plt.show()

# Guess: The correlation appears to be positive (as study hours increase, exam scores increase).

# Calculate correlation coefficient
correlation = np.corrcoef(study_hours, exam_scores)[0, 1]
print(f"Correlation coefficient: {correlation:.3f}")
# Out:
# Correlation coefficient: 0.981
