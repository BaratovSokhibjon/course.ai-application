# %% [markdown]
# # Lecture 3: Data Analysis with Python

# %% [markdown]
# ## Understanding the Dataset
# - Brief description of the dataset (source, type of data)
# - Number of samples and features (rows × columns)
# - Purpose of the dataset (prediction, classification, regression)
# - Feature Types: Numerical, Categorical, Datetime

# %% [markdown]
# ## Descriptive Analytics
# Descriptive statistics provide a summary of data features:
# - Minimum (Min)
# - Maximum (Max)
# - Mean
# - Median
# - Standard Deviation (SD)
# - Range

# %%
import numpy as np
import pandas as pd

data = [5, 8, 12, 12, 20]
series = pd.Series(data)

print("Minimum:", series.min())
print("Maximum:", series.max())
print("Mean:", series.mean())
print("Median:", series.median())
print("Standard Deviation:", series.std())
print("Range:", series.max() - series.min())
# Out:
# Minimum: 5
# Maximum: 20
# Mean: 11.4
# Median: 12.0
# Standard Deviation: 5.639148871948674
# Range: 15

# %% [markdown]
# ## Data Distribution & Visualization
# Visualizations help us understand data distribution:
# - Boxplot
# - Histogram
# - Line Chart

# %%
import matplotlib.pyplot as plt

data = [5, 8, 12, 12, 20]

# Boxplot
plt.figure(figsize=(6,4))
plt.boxplot(data)
plt.title("Boxplot of Dataset")
plt.show()

# Histogram
plt.figure(figsize=(6,4))
plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.title("Histogram of Dataset")
plt.show()

# Line chart
plt.figure(figsize=(6,4))
plt.plot(data, marker='o', color='green')
plt.title("Line Chart of Dataset")
plt.show()

# %% [markdown]
# ## Data Correlation
# - Correlation shows the relationship between two variables
# - Range: -1 (negative) to +1 (positive)
# - Tools: Scatter plot, Heatmap, Line chart

# %%
import seaborn as sns

data = pd.DataFrame({
    "Study_Hours": [2, 4, 6, 8, 10],
    "Exam_Scores": [50, 60, 65, 70, 85]
})

# Scatter plot
plt.scatter(data["Study_Hours"], data["Exam_Scores"], color="orange")
plt.title("Study Hours vs Exam Scores")
plt.xlabel("Study Hours")
plt.ylabel("Exam Scores")
plt.show()

# Correlation Heatmap
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# Line chart
plt.plot(data["Study_Hours"], label="Study Hours", marker="o")
plt.plot(data["Exam_Scores"], label="Exam Scores", marker="x")
plt.legend()
plt.title("Line Chart of Study Hours & Exam Scores")
plt.show()

# %% [markdown]
# ## Handling Duplicates and Missing Values
# - Drop duplicates
# - Handle missing numeric values (mean, median, mode)
# - Handle missing categorical values (mode, ML imputation)

# %%
# Example with artificial dataset
df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Carol", "Dave", "Eve"],
    "Age": [20, None, 19, 21, 22],
    "Grade": ["A", None, None, "B", "A"],
    "Score": [90, 85, 78, None, 88]
})

print("Initial missing values:\n", df.isnull().sum())

# Fill numeric with median
num_cols = df.select_dtypes(include=['int64','float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# Fill categorical with mode
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

print("\nAfter cleaning:\n", df)
# Out:
# Initial missing values:
#  Name     0
# Age      1
# Grade    2
# Score    1
# dtype: int64
#
# After cleaning:
#      Name   Age Grade  Score
# 0  Alice  20.0     A   90.0
# 1    Bob  20.5     A   85.0
# 2  Carol  19.0     A   78.0
# 3   Dave  21.0     B   86.5
# 4    Eve  22.0     A   88.0

# %% [markdown]
# ## Class Activities
# ### Activity 1
# Dataset: [3, 7, 9, 15, 21, 21, 30]
# 1. Convert to pandas Series
# 2. Calculate min, max, mean, median, std, range
# 3. Compare mean & median
#
# ### Activity 2
# Dataset: [4, 7, 7, 10, 12, 15, 18]
# 1. Boxplot (find outliers)
# 2. Histogram (bins=3, then bins=5)
# 3. Line chart
#
# ### Activity 3
# Hours_Sleep vs Productivity_Score
#
# | Hours_Sleep | Productivity_Score |
# |-------------|---------------------|
# | 4 | 50 |
# | 5 | 55 |
# | 6 | 60 |
# | 7 | 65 |
# | 8 | 80 |
#
# 1. Scatter plot
# 2. Correlation coefficient
# 3. Line chart
#
# ### Activity 4
# Dataset with missing values (Name, Age, Grade, Score)
# 1. Check missing
# 2. Fill numeric with median
# 3. Fill categorical with mode
# 4. Verify
